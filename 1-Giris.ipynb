# %% [markdown]
# - Seaborn
# - Matplotlib
# - ggplot
# - plotly ( interaktif)
# - pandas
# - mıssıngno
# - networkX
# - bokeh
# - pygal
# - geoplotlib
# - gleam
# - leather

# %% [markdown]
# - 1- Irıs Speices
# - 2-Significant Eartqueakes
# - 3- Aerial Bombing Operations in world war 2
# - 4- weather conditions in world war two
# - 5- world unıversity rankings
# - 6- fatal police shootings in the us
# - 7- titanic
